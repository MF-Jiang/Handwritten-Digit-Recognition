# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split

# import threadpoolctl
# threadpoolctl.threadpool_limits(1)

# %%
# # Check if the data file already exists
# try:
#     data = np.load('mnist_data.npz', allow_pickle=True)
#     X_small = data['X_small']
#     y_small = data['y_small']
# #     print(y_small)
# except FileNotFoundError:
#     # If the data file does not exist, download and save the data
#     X, y = fetch_openml('mnist_784', data_home='./', return_X_y=True)
#     X = X / 255.
#     X_small = X[:5000]
#     y_small = y[:5000]
#     # Save the data
#     np.savez('mnist_data.npz', X_small=X_small, y_small=y_small)
    
# X_train, X_test, y_train, y_test = train_test_split(X_small, y_small, test_size=0.2, random_state=42)

# %%
# read data function
import gzip
import os
import struct
import numpy as np
import gzip

def load_mnist_train(path, kind='train'): 
    labels_path = os.path.join(path,'%s-labels-idx1-ubyte.gz'% kind)
    images_path = os.path.join(path,'%s-images-idx3-ubyte.gz'% kind)
    with gzip.open(labels_path, 'rb') as lbpath:
        magic, n = struct.unpack('>II',lbpath.read(8))
        labels = np.fromstring(lbpath.read(),dtype=np.uint8)
    with gzip.open(images_path, 'rb') as imgpath:
        magic, num, rows, cols = struct.unpack('>IIII',imgpath.read(16))
        images = np.fromstring(imgpath.read(),dtype=np.uint8).reshape(len(labels), 784)
    return images, labels

def load_mnist_test(path, kind='t10k'): 
    labels_path = os.path.join(path,'%s-labels-idx1-ubyte.gz'% kind)
    images_path = os.path.join(path,'%s-images-idx3-ubyte.gz'% kind)
    with gzip.open(labels_path, 'rb') as lbpath:
        magic, n = struct.unpack('>II',lbpath.read(8))
        labels = np.fromstring(lbpath.read(),dtype=np.uint8)
    with gzip.open(images_path, 'rb') as imgpath:
        magic, num, rows, cols = struct.unpack('>IIII',imgpath.read(16))
        images = np.fromstring(imgpath.read(),dtype=np.uint8).reshape(len(labels), 784)
    return images, labels

X_train,y_train = load_mnist_train('./data', kind='train')
X_test, y_test = load_mnist_test('./data', kind='t10k')
X_train = X_train[:10000]
y_train = y_train[:10000]
X_test = X_test[:1000]
y_test = y_test[:1000]
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_29928\2133176266.py:13: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   labels = np.fromstring(lbpath.read(),dtype=np.uint8)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_29928\2133176266.py:16: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   images = np.fromstring(imgpath.read(),dtype=np.uint8).reshape(len(labels), 784)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_29928\2133176266.py:24: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   labels = np.fromstring(lbpath.read(),dtype=np.uint8)
# ...

# %%
from sklearn.cluster import KMeans
n_clusters=10
kmeans = KMeans(n_clusters=n_clusters).fit(X_train)
# kmeans = KMeans(n_clusters=n_clusters).fit(X_small)
cluster_centers = kmeans.cluster_centers_.reshape(-1, 28, 28)

for i in range(n_clusters):
    plt.subplot(2, 5, i + 1)
    plt.imshow(cluster_centers[i], cmap='gray')
    plt.title(f'Cluster{i}')
    plt.axis('off')
plt.show()
# Out:
# D:\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
# kmeans.labels_=y_small
kmeans.labels_=y_train
cluster_labels = kmeans.predict(X_test)

# %%
cluster_digit_distribution = {i: {str(j): 0 for j in range(n_clusters)} for i in range(n_clusters)}

for i, label in enumerate(cluster_labels):
    true_digit = int(y_test[i])
    cluster_digit_distribution[label][str(true_digit)] += 1

for i in range(n_clusters):
    print(f'Cluster {i} Digit Distribution:')
    for j in range(n_clusters):
        print(f'Digit {j}: {cluster_digit_distribution[i][str(j)]} samples')
# Out:
# Cluster 0 Digit Distribution:
# Digit 0: 1 samples
# Digit 1: 101 samples
# Digit 2: 16 samples
# Digit 3: 19 samples
# Digit 4: 3 samples
# Digit 5: 13 samples
# Digit 6: 5 samples
# Digit 7: 12 samples
# Digit 8: 5 samples
# Digit 9: 2 samples
# Cluster 1 Digit Distribution:
# Digit 0: 0 samples
# Digit 1: 0 samples
# Digit 2: 1 samples
# Digit 3: 2 samples
# Digit 4: 39 samples
# Digit 5: 7 samples
# Digit 6: 0 samples
# Digit 7: 53 samples
# Digit 8: 6 samples
# Digit 9: 40 samples
# Cluster 2 Digit Distribution:
# Digit 0: 6 samples
# Digit 1: 0 samples
# Digit 2: 4 samples
# Digit 3: 1 samples
# Digit 4: 0 samples
# Digit 5: 15 samples
# Digit 6: 3 samples
# Digit 7: 0 samples
# Digit 8: 41 samples
# Digit 9: 1 samples
# Cluster 3 Digit Distribution:
# Digit 0: 0 samples
# Digit 1: 25 samples
# Digit 2: 17 samples
# Digit 3: 0 samples
# Digit 4: 1 samples
# Digit 5: 0 samples
# Digit 6: 0 samples
# Digit 7: 1 samples
# Digit 8: 1 samples
# Digit 9: 0 samples
# ...

# %%
for i in range(n_clusters):
    cluster_label = i
    cluster_data = [cluster_digit_distribution[i][str(j)] for j in range(n_clusters)]
    plt.figure()
    plt.bar(range(n_clusters), cluster_data, tick_label=[str(j) for j in range(n_clusters)])
    plt.title(f'Clustering {cluster_label}')
    plt.xlabel('label')
    plt.ylabel('num')
    plt.show()

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, cluster_labels)
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# Accuracy: 4.30%

# %%
cluster_to_true_label = {}
for i in range(10):
    cluster_label = i
    cluster_indices = [index for index, label in enumerate(cluster_labels) if label == cluster_label]
    cluster_true_labels = [int(y_test[index]) for index in cluster_indices]
    most_common_label = max(set(cluster_true_labels), key=cluster_true_labels.count)
    cluster_to_true_label[cluster_label] = most_common_label


mapped_labels = [cluster_to_true_label[label] for label in cluster_labels]


accuracy = sum(1 for i in range(len(y_test)) if int(y_test[i]) == mapped_labels[i]) / len(y_test)
print(f"K-Means Accuracy: {accuracy * 100:.2f}%")
# Out:
# K-Means Accuracy: 55.70%

# %%
print("X_test first 20:")
plt.figure(figsize=(10, 2))
for i in range(20):
    plt.subplot(1, 20, i + 1)
    plt.imshow(X_test[i].reshape(28, 28), cmap='gray')
#     plt.title(f"True: {y_test[i]}")
#     cluster_label = cluster_labels[i]
#     plt.title(f"Cluster: {cluster_label}")
    mapped_label = mapped_labels[i]
    plt.title(f"{mapped_label}")
    plt.axis('off')
plt.show()
# Out:
# X_test first 20:

# %%
# 打印每个簇的标签和对应的图像
for i in range(10):
    cluster_label = i
    cluster_indices = [index for index, label in enumerate(cluster_labels) if label == cluster_label]
    cluster_images = X_test[cluster_indices]
    cluster_true_labels = [int(y_test[index]) for index in cluster_indices]

    print(f"Cluster {cluster_label}:")
#     print(cluster_true_labels)

    plt.figure(figsize=(10, 2))
    for j in range(len(cluster_images)):
        plt.subplot(1, len(cluster_images), j + 1)
        plt.imshow(cluster_images[j].reshape(28, 28), cmap='gray')
        plt.title(f"{cluster_true_labels[j]}")
        plt.axis('off')
    plt.show()
# Out:
# Cluster 0:
# Cluster 1:
# Cluster 2:
# Cluster 3:
# Cluster 4:
# Cluster 5:
# Cluster 6:
# Cluster 7:
# Cluster 8:
# Cluster 9:

# %%
predicted_cluster_labels = [int(cluster_to_true_label[label]) for label in range(10)]
print(f"K-Means 分配的标签: {predicted_cluster_labels}")
# Out:
# K-Means 分配的标签: [1, 7, 8, 1, 0, 6, 7, 4, 3, 2]
